# %% [markdown]
# # Web Scraping Lab
#
# You will find in this notebook some scrapy exercises to practise your scraping skills.
#
# **Tips:**
#
# - Check the response status code for each request to ensure you have obtained the intended contennt.
# - Print the response text in each request to understand the kind of info you are getting and its format.
# - Check for patterns in the response text to extract the data/info requested in each question.
# - Visit each url and take a look at its source through Chrome DevTools. You'll need to identify the html tags, special class names etc. used for the html content you are expected to extract.

# %% [markdown]
# - [Requests library](http://docs.python-requests.org/en/master/#the-user-guide) documentation
# - [Beautiful Soup Doc](https://www.crummy.com/software/BeautifulSoup/bs4/doc/)
# - [Urllib](https://docs.python.org/3/library/urllib.html#module-urllib)
# - [re lib](https://docs.python.org/3/library/re.html)
# - [lxml lib](https://lxml.de/)
# - [Scrapy](https://scrapy.org/)
# - [List of HTTP status codes](https://en.wikipedia.org/wiki/List_of_HTTP_status_codes)
# - [HTML basics](http://www.simplehtmlguide.com/cheatsheet.php)
# - [CSS basics](https://www.cssbasics.com/#page_start)

# %% [markdown]
# #### Below are the libraries and modules you may need. `requests`,  `BeautifulSoup` and `pandas` are imported for you. If you prefer to use additional libraries feel free to uncomment them.

# %%
import requests
from bs4 import BeautifulSoup
import pandas as pd


# from pprint import pprint
# from lxml import html
# from lxml.html import fromstring
# import urllib.request
# from urllib.request import urlopen
# import random
# import re
# import scrapy

# %% [markdown]
# #### Download, parse (using BeautifulSoup), and print the content from the Trending Developers page from GitHub:

# %%
# This is the url you will scrape in this exercise
url = 'https://github.com/trending/developers'

# %%
#your code

'''
L.S. Good!
'''

html = requests.get(url).content
#html[0:600]

soup = BeautifulSoup(html, "lxml")
soup
# Out:
# <!DOCTYPE html>
# <html lang="en">
# <head>
# <meta charset="utf-8"/>
# <link href="https://github.githubassets.com" rel="dns-prefetch"/>
# <link href="https://avatars0.githubusercontent.com" rel="dns-prefetch"/>
# <link href="https://avatars1.githubusercontent.com" rel="dns-prefetch"/>
# <link href="https://avatars2.githubusercontent.com" rel="dns-prefetch"/>
# <link href="https://avatars3.githubusercontent.com" rel="dns-prefetch"/>
# <link href="https://github-cloud.s3.amazonaws.com" rel="dns-prefetch"/>
# <link href="https://user-images.githubusercontent.com/" rel="dns-prefetch"/>
# <link crossorigin="anonymous" href="https://github.githubassets.com/assets/frameworks-2fd1891c9e6292401a1a3de8bc3f747f.css" integrity="sha512-4bmhxCob3U2WoK8HVl7UacoDdNejo+50BlGN9SdGtjXbsCQwp7uLtntLkL9a9CmgLPZ8L9lsOZL0ieINT9yHeA==" media="all" rel="stylesheet"/>
# ...

# %% [markdown]
# #### Display the names of the trending developers retrieved in the previous step.
#
# Your output should be a Python list of developer names. Each name should not contain any html tag.
#
# **Instructions:**
#
# 1. Find out the html tag and class names used for the developer names. You can achieve this using Chrome DevTools.
#
# 1. Use BeautifulSoup to extract all the html elements that contain the developer names.
#
# 1. Use string manipulation techniques to replace whitespaces and linebreaks (i.e. `\n`) in the *text* of each html element. Use a list to store the clean names.
#
# 1. Print the list of names.
#
# Your output should look like below:
#
# ```
# ['trimstray (@trimstray)',
#  'joewalnes (JoeWalnes)',
#  'charlax (Charles-AxelDein)',
#  'ForrestKnight (ForrestKnight)',
#  'revery-ui (revery-ui)',
#  'alibaba (Alibaba)',
#  'Microsoft (Microsoft)',
#  'github (GitHub)',
#  'facebook (Facebook)',
#  'boazsegev (Bo)',
#  'google (Google)',
#  'cloudfetch',
#  'sindresorhus (SindreSorhus)',
#  'tensorflow',
#  'apache (TheApacheSoftwareFoundation)',
#  'DevonCrawford (DevonCrawford)',
#  'ARMmbed (ArmMbed)',
#  'vuejs (vuejs)',
#  'fastai (fast.ai)',
#  'QiShaoXuan (Qi)',
#  'joelparkerhenderson (JoelParkerHenderson)',
#  'torvalds (LinusTorvalds)',
#  'CyC2018',
#  'komeiji-satori (神楽坂覚々)',
#  'script-8']
#  ```

# %%
# Get the names of developers


table = soup.find_all('h1', {'class': 'h3 lh-condensed'})

names = [row.text.strip().split("\n") for row in table]

names_2 = [y for x in names for y in x]
#print(names_2)


# Get the nicks of developers

table2 = soup.find_all('p', {'class': 'f4 text-normal mb-1'})

nicks = [row.text.strip().split("\n") for row in table2]

nicks_2 = [y for x in nicks for y in x]
#print(nicks_2)


# Create a list of names and nicks of developers 

ziplist_2 = [x + ' (' + y + ')' for (x, y) in zip(names_2, nicks_2)]
print(ziplist_2)
# Out:
# ['Paulus Schoutsen (balloob)', 'Florian Märkl (thestr4ng3r)', 'Arvid Norberg (arvidn)', 'Vincent Composieux (eko)', 'Ofek Lev (ofek)', 'Geoffrey Huntley (ghuntley)', 'Felix Angelov (felangel)', 'Felix Breuer (breuerfelix)', 'Martin Atkins (apparentlymart)', 'Sébastien Eustace (sdispater)', 'JP Simard (jpsim)', 'Jack Lloyd (randombit)', 'Stefan Prodan (stefanprodan)', 'Guillaume Gomez (GuillaumeGomez)', 'Michael E. Karpeles (mekarpeles)', 'Eileen McNaughton (eileenmcnaughton)', 'Sascha Grunert (saschagrunert)', 'Lukas Taegert-Atkinson (lukastaegert)', 'Surmon (surmon-china)', 'William Candillon (wcandillon)', 'Andreas Mueller (amueller)', 'Koen Kanters (Koenkk)', 'Gabriel Rubens (fakenickels)', 'Joe Block (unixorn)', 'Ben Hollis (bhollis)']

# %% [markdown]
# #### Display the trending Python repositories in GitHub
#
# The steps to solve this problem is similar to the previous one except that you need to find out the repository names instead of developer names.

# %%
# This is the url you will scrape in this exercise
url = 'https://github.com/trending/python?since=daily'

# %%
#your code

html = requests.get(url).content

soup = BeautifulSoup(html, "lxml")
#soup

tags = ['h1']
text = [element.text for element in soup.find_all(tags)][1:]
#print(text)

new_text = []

for item in text:
    x = item.strip()
    new_text.append(x)

#print(new_text)

clean_text = []

for i in new_text:
    new = i.replace('\n','')
    new2 = new.replace('      ', ' ')
    clean_text.append(new2)
              
'''
L.S. Yes, very good!
'''        
        
print(clean_text)
# Out:
# ['ownthink / KnowledgeGraphData', 'gto76 / python-cheatsheet', 'elastic / helm-charts', 'notadamking / tensortrade', 'pytorch / botorch', 'Avik-Jain / 100-Days-of-ML-Code-Chinese-Version', 'volatilityfoundation / volatility', 'ownthink / Jiagu', 'qq547276542 / Agriculture_KnowledgeGraph', 'metachar / PhoneSploit', 'mlflow / mlflow', 'cornellius-gp / gpytorch', 'scikit-learn / scikit-learn', 'swisskyrepo / PayloadsAllTheThings', 'eriklindernoren / PyTorch-YOLOv3', 'Star-Clouds / centerface', 'allenai / allennlp', 'nccgroup / ScoutSuite', 'getsentry / sentry', 'ansible / awx', 'microsoft / nni', 'nuno-faria / tiler', 'vishnubob / wait-for-it', 'pytest-dev / pytest', 'ansible / ansible']

# %% [markdown]
# #### Display all the image links from Walt Disney wikipedia page

# %%
# This is the url you will scrape in this exercise
url = 'https://en.wikipedia.org/wiki/Walt_Disney'

# %%
#your code

'''
L.S. Well done!
'''

html = requests.get(url).content

soup = BeautifulSoup(html, "lxml")
soup
  
images = []
for img in soup.findAll('img'):
    images.append(img.get('src'))

print(images)
# Out:
# ['//upload.wikimedia.org/wikipedia/en/thumb/e/e7/Cscr-featured.svg/20px-Cscr-featured.svg.png', '//upload.wikimedia.org/wikipedia/en/thumb/1/1b/Semi-protection-shackle.svg/20px-Semi-protection-shackle.svg.png', '//upload.wikimedia.org/wikipedia/commons/thumb/d/df/Walt_Disney_1946.JPG/220px-Walt_Disney_1946.JPG', '//upload.wikimedia.org/wikipedia/commons/thumb/8/87/Walt_Disney_1942_signature.svg/150px-Walt_Disney_1942_signature.svg.png', '//upload.wikimedia.org/wikipedia/commons/thumb/c/c4/Walt_Disney_envelope_ca._1921.jpg/220px-Walt_Disney_envelope_ca._1921.jpg', '//upload.wikimedia.org/wikipedia/commons/thumb/4/4d/Newman_Laugh-O-Gram_%281921%29.webm/220px-seek%3D2-Newman_Laugh-O-Gram_%281921%29.webm.jpg', '//upload.wikimedia.org/wikipedia/commons/thumb/0/0d/Trolley_Troubles_poster.jpg/170px-Trolley_Troubles_poster.jpg', '//upload.wikimedia.org/wikipedia/commons/thumb/7/71/Walt_Disney_and_his_cartoon_creation_%22Mickey_Mouse%22_-_National_Board_of_Review_Magazine.jpg/170px-Walt_Disne
# ...

# %% [markdown]
# #### Retrieve an arbitary Wikipedia page of "Python" and create a list of links on that page

# %%
# This is the url you will scrape in this exercise
url ='https://en.wikipedia.org/wiki/Python' 

'''
L.S. It is good practice to import modules at the beginning of the notebook. 
'''

import re

# %%
#your code

'''
L.S. Good!
'''

html = requests.get(url).content

soup = BeautifulSoup(html, "lxml")
#print(soup)

links  = []

for link in soup.find_all('a', attrs={'href': re.compile("http")}):
    links.append(link.get('href'))


print(links)
# Out:
# ['https://en.wiktionary.org/wiki/Python', 'https://en.wiktionary.org/wiki/python', 'https://en.wikipedia.org/w/index.php?title=Special:WhatLinksHere/Python&namespace=0', 'https://en.wikipedia.org/w/index.php?title=Python&oldid=922464701', 'https://donate.wikimedia.org/wiki/Special:FundraiserRedirector?utm_source=donate&utm_medium=sidebar&utm_campaign=C13_en.wikipedia.org&uselang=en', 'https://www.wikidata.org/wiki/Special:EntityPage/Q747452', 'https://commons.wikimedia.org/wiki/Category:Python', 'https://af.wikipedia.org/wiki/Python', 'https://als.wikipedia.org/wiki/Python', 'https://az.wikipedia.org/wiki/Python', 'https://bn.wikipedia.org/wiki/%E0%A6%AA%E0%A6%BE%E0%A6%87%E0%A6%A5%E0%A6%A8_(%E0%A6%A6%E0%A7%8D%E0%A6%AC%E0%A7%8D%E0%A6%AF%E0%A6%B0%E0%A7%8D%E0%A6%A5%E0%A6%A4%E0%A6%BE_%E0%A6%A8%E0%A6%BF%E0%A6%B0%E0%A6%B8%E0%A6%A8)', 'https://be.wikipedia.org/wiki/Python', 'https://bg.wikipedia.org/wiki/%D0%9F%D0%B8%D1%82%D0%BE%D0%BD_(%D0%BF%D0%BE%D1%8F%D1%81%D0%BD%D0%B5%D0%BD%D0%B8%D0%B5)
# ...

# %% [markdown]
# #### A Python list with the top ten FBI's Most Wanted names

# %%
# This is the url you will scrape in this exercise
url = 'https://www.fbi.gov/wanted/topten'

# %%
#your code 

'''
L.S. Well done! Very nice!
'''

html = requests.get(url).content
soup = BeautifulSoup(html, "lxml")

tags = ['h3']
text = [element.text for element in soup.find_all(tags)]
#print(text)

text_2 = []

for name in text:
    x = name.replace('\n','')
    text_2.append(x)

text_2
# Out:
# ['SANTIAGO VILLALBA MEDEROS',
#  'RAFAEL CARO-QUINTERO',
#  'ROBERT WILLIAM FISHER',
#  'BHADRESHKUMAR CHETANBHAI PATEL',
#  'ARNOLDO JIMENEZ',
#  'ALEJANDRO ROSALES CASTILLO',
#  'YASER ABDEL SAID',
#  'JASON DEREK BROWN',
#  'ALEXIS FLORES',
#  'EUGENE PALMER']

# %% [markdown]
# ####  20 latest earthquakes info (date, time, latitude, longitude and region name) by the EMSC as a pandas dataframe

# %%
# This is the url you will scrape in this exercise
url = 'https://www.emsc-csem.org/Earthquake/'

# %%
#your code

html = requests.get(url).content
soup = BeautifulSoup(html, "lxml")

# %%
# Selecting the table
table = soup.find_all('tbody', {'id': 'tbody'})[0]

rows = table.find_all('tr')
#rows

# Split fields using 'td' tag
rows2 = [row.find_all('td') for row in rows]
#print(rows2)

text = [[x.text for x in row] for row in rows2]
#print(text)

earthq = pd.DataFrame(text)

# Cleaning the DataFrame

'''
L.S. Yes, this works, but for next time, when you find yourself copy-pasting a lot, try to make a loop. 
'''


del earthq[0]
del earthq[1]
del earthq[2]
del earthq[3]
del earthq[8]
del earthq[9]
del earthq[10]

col_names = ['Latitude', 'N_S', 'Longitude','W_E','Region','Date_time']

earthq.columns = col_names

earthq.head(20)
# Out:
#    Latitude  N_S Longitude  W_E                             Region  \
# 0    42.38   N     144.37   E               HOKKAIDO, JAPAN REGION
# 1    35.41   N      97.88   W                             OKLAHOMA
# 2     0.17   S     125.08   E                          MOLUCCA SEA
# 3    65.71   N     165.19   W                      NORTHERN ALASKA
# 4    36.49   N      28.62   E     DODECANESE IS.-TURKEY BORDER REG
# 5    56.35   N     149.18   W                       GULF OF ALASKA
# 6    26.88   N      86.59   E            NEPAL-INDIA BORDER REGION
# 7    11.02   S     121.45   E                       SOUTH OF TIMOR
# 8    15.68   N      95.04   W              OFFSHORE OAXACA, MEXICO
# 9    66.37   N     157.51   W                      NORTHERN ALASKA
# 10   19.55   N      64.65   W                VIRGIN ISLANDS REGION
# 11   16.29   N      98.25   W                       OAXACA, MEXICO
# 12   27.07   N      55.09   E                        SOUTHERN IRAN
# ...

# %% [markdown]
# #### Display the date, days, title, city, country of next 25 hackathon events as a Pandas dataframe table

# %%
# This is the url you will scrape in this exercise
url ='https://hackevents.co/hackathons'

# %%
#your code

html = requests.get(url).content
soup = BeautifulSoup(html, "html.parser")

table = soup.find_all('h5', {'class':'card-title'})
table2 = soup.find_all('p', {'class':'card-text'})

name = [row.text.strip().split("\n") for row in table]
name2 = [y for x in name for y in x]
print(name2)

'''
L.S. Very nice!
'''

date = [row.text.strip().split("\n") for row in table2]
date2 = [y for x in date for y in x]
print(date2)
# Out:
# ['Oerlikon Digital Hub Hackathon']
# ['11/8/2019']

# %% [markdown]
# #### Count number of tweets by a given Twitter account.

# %% [markdown]
# You will need to include a ***try/except block*** for account names not found.
# <br>***Hint:*** the program should count the number of tweets for any provided account

# %%
# This is the url you will scrape in this exercise 
# You will need to add the account credentials to this url
url = 'https://twitter.com/'

# %%
#your code

# %% [markdown]
# #### Number of followers of a given twitter account

# %% [markdown]
# You will need to include a ***try/except block*** in case account/s name not found.
# <br>***Hint:*** the program should count the followers for any provided account

# %%
# This is the url you will scrape in this exercise 
# You will need to add the account credentials to this url
url = 'https://twitter.com/'

# %%
#your code



#username = input('Enter your username: ')
#complete_url= 'https://twitter.com/{}'.format(username)
#print(complete_url)

#html = requests.get(complete_url).content
#soup = BeautifulSoup(html, "lxml")

#table = soup.find_all('div', {'class': 'css-1dbjc4n r-18u37iz'})
#table

# %% [markdown]
# ### BONUS QUESTIONS

# %% [markdown]
# #### List all language names and number of related articles in the order they appear in wikipedia.org

# %%
# This is the url you will scrape in this exercise
url = 'https://www.wikipedia.org/'

# %%
#your code

html = requests.get(url).content
soup = BeautifulSoup(html, "lxml")


# Get the number of related articles

table = soup.find_all('h2', {'class':'bookshelf-container'})

'''
L.S. Something went wrong here. Please proof-run your code next time. 
'''

articles = [row.text.strip().split("\n") for row in table]
articles2 = [y for x in articles for y in x]
    
articles4 = [x for x in articles3 if x]
print(articles4)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-20-13c51ebac8d3> in <module>()
#      12 articles2 = [y for x in articles for y in x]
#      13
# ---> 14 articles4 = [x for x in articles3 if x]
#      15 print(articles4)
#
# NameError: name 'articles3' is not defined

# %%
# 1 000 000+ articles
table2 = soup.find_all('div', {'class':'langlist langlist-large hlist'})[0]
table2

large = [table2.text.strip().split("\n")]
large_1 = [y for x in large for y in x]
dict1 = {articles4[0]:large_1}
print(dict1)

# 100 000+ articles
table3 = soup.find_all('div', {'class':'langlist langlist-large hlist'})[1]
table3

l_2 = [table3.text.strip().split("\n")]
large_2 = [y for x in l_2 for y in x]
dict2 = {articles4[2]:large_2}
print(dict2)


# 10 000+ articles

table4 = soup.find_all('div', {'class':'langlist hlist'})[0]
table4

medium = [table4.text.strip().split("\n")]
medium_1 = [y for x in medium for y in x]
dict3 = {articles4[4]:medium_1}
print(dict3)

# 1 000+ articles

table5 = soup.find_all('div', {'class':'langlist hlist'})[1]
table5

m_2 = [table5.text.strip().split("\n")]
medium_2 = [y for x in m_2 for y in x]
dict4 = {articles4[6]:medium_2}
print(dict4)

# 100+ articles

table6 = soup.find_all('div', {'class':'langlist langlist-tiny hlist'})[0]
table6

small = [table6.text.strip().split("\n")]
small_1 = [y for x in small for y in x]
dict5 = {articles4[8]:small_1}
print(dict5)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-21-4fab9444073e> in <module>()
#       5 large = [table2.text.strip().split("\n")]
#       6 large_1 = [y for x in large for y in x]
# ----> 7 dict1 = {articles4[0]:large_1}
#       8 print(dict1)
#       9
#
# NameError: name 'articles4' is not defined

# %% [markdown]
# #### A list with the different kind of datasets available in data.gov.uk

# %%
# This is the url you will scrape in this exercise
url = 'https://data.gov.uk/'

# %%
#your code 

'''
L.S. Very good!
'''

html = requests.get(url).content
soup = BeautifulSoup(html, "lxml")

tags = ['h2']
text = [element.text for element in soup.find_all(tags)]
print(text)
# Out:
# ['Business and economy', 'Crime and justice', 'Defence', 'Education', 'Environment', 'Government', 'Government spending', 'Health', 'Mapping', 'Society', 'Towns and cities', 'Transport']

# %% [markdown]
# #### Top 10 languages by number of native speakers stored in a Pandas Dataframe

# %%
# This is the url you will scrape in this exercise
url = 'https://en.wikipedia.org/wiki/List_of_languages_by_number_of_native_speakers'

# %%
#your code

'''
L.S. Well done!
'''



html = requests.get(url).content
soup = BeautifulSoup(html, "lxml")

table = soup.find_all('table')[0]
table

rows = table.find_all('tr')
rows

rows2 = [row.find_all('td') for row in rows]
rows2

text = [[x.text for x in row] for row in rows2]
#print(text)

text2 = []
for i in text:
    sub = []
    for x in i:
        y = x.rstrip('\n')
        sub.append(y)
    text2.append(sub)
    
#print(text2)

col_names = ['Rank', 'Language', 'Primary Country', 'Total Countries', 'Speakers', '% of the World population', 'Language Family']


lang_df = pd.DataFrame(text2, columns = col_names)
lang_df.head()

lang_df_2 = lang_df.drop(lang_df.index[0])
lang_df_2.head()
# Out:
#   Rank                       Language Primary Country Total Countries  \
# 1    1  Mandarin (language family)[9]           China              13
# 2    2                        Spanish           Spain              31
# 3    3                        English  United Kingdom             137
# 4    4                      Hindi[10]           India               4
# 5    5                        Bengali      Bangladesh               4
#
#   Speakers % of the World population          Language Family
# 1      918                    11.922      Sino-TibetanSinitic
# 2      480                     5.994     Indo-EuropeanRomance
# 3      379                     4.922    Indo-EuropeanGermanic
# 4      341                     4.429  Indo-EuropeanIndo-Aryan
# 5      228                     2.961  Indo-EuropeanIndo-Aryan

# %% [markdown]
# #### Scrape a certain number of tweets of a given Twitter account.

# %%
# This is the url you will scrape in this exercise 
# You will need to add the account credentials to this url
url = 'https://twitter.com/'

# %%
# your code

# %% [markdown]
# #### IMDB's Top 250 data (movie name, Initial release, director name and stars) as a pandas dataframe

# %%
# This is the url you will scrape in this exercise 
url = 'https://www.imdb.com/chart/top'

# %%
# your code

# %% [markdown]
# #### Movie name, year and a brief summary of the top 10 random movies (IMDB) as a pandas dataframe.

# %%
#This is the url you will scrape in this exercise
url = 'http://www.imdb.com/chart/top'

# %%
#your code

# %% [markdown]
# #### Find the live weather report (temperature, wind speed, description and weather) of a given city.

# %%
#https://openweathermap.org/current
city = city=input('Enter the city:')
url = 'http://api.openweathermap.org/data/2.5/weather?'+'q='+city+'&APPID=b35975e18dc93725acb092f7272cc6b8&units=metric'

# %%
# your code

# %% [markdown]
# #### Book name,price and stock availability as a pandas dataframe.

# %%
# This is the url you will scrape in this exercise. 
# It is a fictional bookstore created to be scraped. 
url = 'http://books.toscrape.com/'

# %%
#your code
